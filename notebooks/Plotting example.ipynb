# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import datetime
import glob
import pickle
from datetime import datetime, timedelta
import sys

#import the folder that has the analysis level class
sys.path.append("../CombinedData/")
import Dataset

# %%
#top directory of datasets, containing sub-folders like "ds05, ..."
#change this to match where you are running this notebook, relative to your data location. 
topdir = "/p/lustre2/nexouser/data/StanfordData/angelico/hv-test-chamber/Run5/"
#the sub-folders
datasets = ["cosmics-5-3/", "ds03/", "ds04/", "ds05/", "ds06/", \
            "ds07/","ds08/","ds09/","ds10/","ds11/","ds12/","ds13/","ds15/","ds16/",\
            "ds17/","ds18/","ds19/","ds20/","ds21/","ds22/","ds23/","ds24/","ds25/"]

#choose a single one, for single dataset exploration
ds_single = "ds20/"

#config file, that contains info on analysis settings
config = "../configs/run5_config.yaml"

# %%
#load the dataset object for the single file selected
ds = Dataset.Dataset(topdir+ds_single, config)

# %%
#look at struck files and count the number of events in each. 
#each struck file has possibly a variable number of events, 
#and they are ordered chronologically in time based on when
#the events arrived. 
for f in ds.struck_files:
    df, date = pickle.load(open(f, "rb")) #opens the pandas dataframe object in the pickle file
    nevts = len(df.index)
    t_i = df["Seconds"].iloc[0] #timestamp of first event in 0th channel in seconds since start of day
    t_f = df["Seconds"].iloc[1]
    #add that seconds value to the date of the dataset, in a python datetime format
    t_i = date + timedelta(seconds=t_i)
    t_f = date + timedelta(seconds=t_f)
    
    print("In file {} there are {:d} events and times ranging from {} to {}".format(f.split('/')[-1], nevts, t_i, t_f))
# Out:
# In file prereduced_0.p there are 785 events and times ranging from 2023-05-10 20:49:18.319905 to 2023-05-10 20:49:18.623966
# In file prereduced_1.p there are 3804 events and times ranging from 2023-05-10 20:52:38.193334 to 2023-05-10 20:52:38.205759
# In file prereduced_10.p there are 4834 events and times ranging from 2023-05-10 21:22:56.006056 to 2023-05-10 21:22:56.125091
# In file prereduced_11.p there are 13845 events and times ranging from 2023-05-10 21:26:18.005301 to 2023-05-10 21:26:18.023240
# In file prereduced_12.p there are 23019 events and times ranging from 2023-05-10 21:29:40.000757 to 2023-05-10 21:29:40.008348
# In file prereduced_13.p there are 27345 events and times ranging from 2023-05-10 21:33:02.002166 to 2023-05-10 21:33:02.005574
# In file prereduced_14.p there are 16673 events and times ranging from 2023-05-10 21:36:24.003263 to 2023-05-10 21:36:24.007940
# In file prereduced_15.p there are 12741 events and times ranging from 2023-05-10 21:39:46.002366 to 2023-05-10 21:39:46.006434
# In file prereduced_16.p there are 646 events and times ranging from 2023-05-10 21:43:08.003539 to 2023-05-10 21:43:08.033484
# In file prereduced_17.p there are 1592 events and times ranging from 2023-05-10 21:46:30.012147 to 2023-05-10 21:46:30.130691
# In file prereduced_18.p there are 7665 events and times ranging from 2023-05-10 21:49:52.032193 to 2023-05-10 21:49:52.041258
# In file prereduced_19.p there are 16126 events and times ranging from 2023-05-10 21:53:14.003882 to 2023-05-10 21:53:14.005299
# In file prereduced_2.p there are 11223 events and times ranging from 2023-05-10 20:56:00.004258 to 2023-05-10 20:56:00.033341
# In file prereduced_20.p there are 24616 events and times ranging from 2023-05-10 21:56:36.003095 to 2023-05-10 21:56:36.008008
# In file prereduced_21.p there are 30508 events and times ranging from 2023-05-10 21:59:58.004349 to 2023-05-10 21:59:58.004451
# In file prereduced_22.p there are 8117 events and times ranging from 2023-05-10 22:03:20.004300 to 2023-05-10 22:03:20.014460
# In file prereduced_23.p there are 7011 events and times ranging from 2023-05-10 22:06:42.054486 to 2023-05-10 22:06:42.130201
# In file prereduced_24.p there are 11844 events and times ranging from 2023-05-10 22:10:04.005781 to 2023-05-10 22:10:04.011972
# In file prereduced_25.p there are 162 events and times ranging from 2023-05-10 22:13:26.574629 to 2023-05-10 22:13:26.814965
# In file prereduced_26.p there are 1891 events and times ranging from 2023-05-10 22:16:48.232107 to 2023-05-10 22:16:50.278219
# In file prereduced_27.p there are 4521 events and times ranging from 2023-05-10 22:20:10.017370 to 2023-05-10 22:20:10.027554
# In file prereduced_28.p there are 418 events and times ranging from 2023-05-10 22:23:32.324366 to 2023-05-10 22:23:32.329144
# In file prereduced_29.p there are 1619 events and times ranging from 2023-05-10 22:26:54.363171 to 2023-05-10 22:26:54.913507
# In file prereduced_3.p there are 20567 events and times ranging from 2023-05-10 20:59:22.001422 to 2023-05-10 20:59:22.008647
# In file prereduced_30.p there are 7840 events and times ranging from 2023-05-10 22:30:16.027110 to 2023-05-10 22:30:16.031289
# In file prereduced_31.p there are 17617 events and times ranging from 2023-05-10 22:33:38.004277 to 2023-05-10 22:33:38.023576
# In file prereduced_32.p there are 25710 events and times ranging from 2023-05-10 22:37:00.002238 to 2023-05-10 22:37:00.006831
# In file prereduced_33.p there are 24039 events and times ranging from 2023-05-10 22:40:22.001096 to 2023-05-10 22:40:22.001936
# In file prereduced_34.p there are 23145 events and times ranging from 2023-05-10 22:43:44.004329 to 2023-05-10 22:43:44.009260
# In file prereduced_35.p there are 9088 events and times ranging from 2023-05-10 22:47:06.002057 to 2023-05-10 22:47:06.006457
# In file prereduced_36.p there are 476 events and times ranging from 2023-05-10 22:50:28.138481 to 2023-05-10 22:50:28.145169
# In file prereduced_37.p there are 2933 events and times ranging from 2023-05-10 22:53:50.106577 to 2023-05-10 22:53:50.146275
# In file prereduced_38.p there are 8462 events and times ranging from 2023-05-10 22:57:12.002492 to 2023-05-10 22:57:12.041068
# In file prereduced_39.p there are 14090 events and times ranging from 2023-05-10 23:00:34.004375 to 2023-05-10 23:00:34.011401
# In file prereduced_4.p there are 27403 events and times ranging from 2023-05-10 21:02:44.001710 to 2023-05-10 21:02:44.002416
# In file prereduced_40.p there are 17457 events and times ranging from 2023-05-10 23:03:56.006360 to 2023-05-10 23:03:56.012120
# In file prereduced_41.p there are 13778 events and times ranging from 2023-05-10 23:07:18.002209 to 2023-05-10 23:07:18.007755
# In file prereduced_42.p there are 11661 events and times ranging from 2023-05-10 23:10:40.003924 to 2023-05-10 23:10:40.008289
# In file prereduced_43.p there are 1991 events and times ranging from 2023-05-10 23:14:02.002171 to 2023-05-10 23:14:02.039182
# In file prereduced_44.p there are 33 events and times ranging from 2023-05-10 23:17:25.614161 to 2023-05-10 23:17:26.705136
# In file prereduced_5.p there are 22610 events and times ranging from 2023-05-10 21:06:06.000292 to 2023-05-10 21:06:06.000971
# In file prereduced_6.p there are 15754 events and times ranging from 2023-05-10 21:09:28.004236 to 2023-05-10 21:09:28.008487
# In file prereduced_7.p there are 23370 events and times ranging from 2023-05-10 21:12:50.003282 to 2023-05-10 21:12:50.003632
# In file prereduced_8.p there are 3417 events and times ranging from 2023-05-10 21:16:12.000305 to 2023-05-10 21:16:12.002728
# In file prereduced_9.p there are 736 events and times ranging from 2023-05-10 21:19:34.260899 to 2023-05-10 21:19:34.623313

# %%
file_of_interest = "prereduced_6.p"

#number of plots desired
nplots = 3

#in the config file, which is loaded by the dataset object, 
#there is a parameter for sampling rate. Grab that (the dataset object has parsed the config file)
dsconf = ds.config
sampling_rate = float(dsconf["struck_reduction"]["clock"]) #Hz 
dT = 1.0/sampling_rate #seconds
dT = dT*1e6 #microseconds

for f in ds.struck_files:
    if(file_of_interest in f):
        df, date = pickle.load(open(f, "rb")) #opens the pandas dataframe object in the pickle file
        nevts = len(df.index)
        #get random, non-repeating event numbers within the bounds of this dataframe
        rand_idx = np.random.choice(range(nevts), nplots, replace=False)
        for idx in rand_idx:
            fig, ax = plt.subplots(figsize=(12, 8))
            evt = df.iloc[idx]
            times = np.arange(0, len(evt["Data"][0])*dT, dT) #times in microseconds
            ax.plot(times, evt["Data"][0], label="channel 0")
            ax.plot(times, evt["Data"][1], label="channel 1")
            ax.set_xlabel("time [us]")
            ax.set_ylabel("signal [mV]")
            ax.set_xlim([0.3, 0.4])
            ax.legend()
            plt.show()
