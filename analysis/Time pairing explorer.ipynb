# %%
import Dataset
import matplotlib.pyplot as plt 
import numpy as np 
# %matplotlib inline
import mpld3
import pickle
import os
import pandas as pd
from pathlib import Path
mpld3.enable_notebook()

plt.style.use("~/evanstyle.mplstyle")

# %%
#initialize dataset 
#topdir = "/home/esiii_lxe/HV-test/8-18-21/13-5kV-pmts/"
topdir = "/home/esiii_lxe/HV-test/8-15-21/10kV-glitch-zoomed/"
#topdir = "/home/esiii_lxe/HV-test/8-19-21/15kV-pmts/"
d = Dataset.Dataset(topdir)
#load dataset raw data, parsing the files
file_prefixes = ["pmt", "anode"]
date_of_dataset = "8-18-21"
d.load_raw(file_prefixes, date_of_dataset)
# Out:
# Looking through files in directory /home/esiii_lxe/HV-test/8-15-21/10kV-glitch-zoomed/ and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 2011
#
#
# Selecting files with prefix anode
# Done: found 2170

# %%
d.pair_by_timestamp(20)
ax = d.plot_timestamp_differences()
ax.set_title("20 ms allowed time difference")
plt.show()


d.pair_by_timestamp(100)
ax = d.plot_timestamp_differences()
ax.set_title("100 ms allowed time difference")
plt.show()
# Out:
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1402 events of 2011 / 2170 due to windowing
# Dividing, : 0.70 / 0.65
# Multiplicities with no distillation: {1: 575, 2: 34}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 575, 2: 34}
# Determining final pairing and saving pairs...:   0%|          | 0/609 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1362 events of 2011 / 2170 due to windowing
# Dividing, : 0.68 / 0.63
# Multiplicities with no distillation: {2: 182, 3: 169, 1: 112, 4: 120, 5: 57, 6: 9}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 572, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/649 [00:00<?, ?it/s]

# %%
#pair events and vary the allowed dt parameter, plotting losses and std 
allowed_dts = np.linspace(10, 150, 10)
cut_efficiency = []
stds = []
means = []
for _ in allowed_dts:
    retvals = d.pair_by_timestamp(_)
    cut_efficiency.append(1 - (retvals[0] + retvals[1])/max(retvals[2]))
    dts = d.get_timestamp_differences()
    stds.append(np.std(dts))
    means.append(np.mean(dts))
# Out:
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1507 events of 2011 / 2170 due to windowing
# Dividing, : 0.75 / 0.69
# Multiplicities with no distillation: {1: 504}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 504}
# Determining final pairing and saving pairs...:   0%|          | 0/504 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1388 events of 2011 / 2170 due to windowing
# Dividing, : 0.69 / 0.64
# Multiplicities with no distillation: {1: 542, 2: 81}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 562, 2: 58, 0: 3}
# Determining final pairing and saving pairs...:   0%|          | 0/623 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1376 events of 2011 / 2170 due to windowing
# Dividing, : 0.68 / 0.63
# Multiplicities with no distillation: {1: 335, 2: 266, 3: 34}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 560, 2: 64, 0: 11}
# Determining final pairing and saving pairs...:   0%|          | 0/635 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1370 events of 2011 / 2170 due to windowing
# Dividing, : 0.68 / 0.63
# Multiplicities with no distillation: {1: 240, 2: 261, 3: 122, 4: 18}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 564, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/641 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1366 events of 2011 / 2170 due to windowing
# Dividing, : 0.68 / 0.63
# Multiplicities with no distillation: {1: 175, 2: 232, 3: 172, 4: 64, 5: 2}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 568, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/645 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1364 events of 2011 / 2170 due to windowing
# Dividing, : 0.68 / 0.63
# Multiplicities with no distillation: {1: 139, 3: 183, 2: 196, 4: 108, 5: 20, 6: 1}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 570, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/647 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1362 events of 2011 / 2170 due to windowing
# Dividing, : 0.68 / 0.63
# Multiplicities with no distillation: {2: 178, 3: 164, 1: 111, 4: 124, 5: 56, 6: 16}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 572, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/649 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1360 events of 2011 / 2170 due to windowing
# Dividing, : 0.68 / 0.63
# Multiplicities with no distillation: {2: 150, 3: 150, 1: 92, 4: 136, 5: 78, 6: 41, 7: 4}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 574, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/651 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1356 events of 2011 / 2170 due to windowing
# Dividing, : 0.67 / 0.62
# Multiplicities with no distillation: {2: 117, 3: 156, 1: 84, 5: 87, 4: 126, 6: 57, 7: 27, 8: 1}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 578, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/655 [00:00<?, ?it/s]
# Finding candidates within allowed_dt: 0it [00:00, ?it/s]
# Lost 1354 events of 2011 / 2170 due to windowing
# Dividing, : 0.67 / 0.62
# Multiplicities with no distillation: {3: 140, 1: 66, 5: 99, 4: 130, 2: 102, 6: 66, 7: 41, 8: 13}
# Distilling repeated candidates : 0it [00:00, ?it/s]
# Multiplicities with distillation: {1: 580, 2: 64, 0: 13}
# Determining final pairing and saving pairs...:   0%|          | 0/657 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(allowed_dts, stds, 'o-', label="standard deviation", linewidth=2)
ax.plot(allowed_dts, means, 'o-', label="mean", linewidth=2)
ax.set_xlabel("cut on time difference during pairing (ms)")
ax.set_ylabel("ms")
ax.legend()
ax2 = ax.twinx()
ax2.patch.set_alpha(0.0)
ax2.plot(allowed_dts, cut_efficiency, label="cut efficiency", color="firebrick", linewidth=2)
ax2.set_ylabel("cut efficiency")
ax2.legend(loc='lower right')
#plt.savefig("allowed_dt_span.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Script for exporting separated file lists for all datasets

# %%
timestamps_df = pd.DataFrame() #dataframe holding dataset name and timestamps
file_prefixes = ["pmt", "anode"]
topdir = "/home/esiii_lxe/HV-test/"
dataset_names = ["8-15-21/10kV-glitch", "8-15-21/10kV-pmts",  "8-15-21/5kV-glitch", "8-15-21/5kV-pmts", "8-16-21/10kV-glitch", "8-18-21/13-5kV-pmts", "8-19-21/15kV-pmts/", "8-19-21/12kV-glitch", "8-19-21/13-5kV-pmts", "8-19-21/15kV-glitch", "8-19-21/17-5kV-glitch", "8-19-21/17-5kV-pmts"]
dataset_dates = [_.split('/')[0] for _ in dataset_names]

for i, ds in enumerate(dataset_names):
    e = pd.Series()
    e["name"] = ds
    d = Dataset.Dataset(topdir+ds)
    d.load_raw(file_prefixes, dataset_dates[i])
    seplists = d.get_separated_filelists()
    for pref in file_prefixes:
        e[pref] = seplists[pref]
    
    timestamps_df = timestamps_df.append(e, ignore_index=True)

print(timestamps_df.head)
# Out:
# Looking through files in directory /home/esiii_lxe/HV-test/8-15-21/10kV-glitch and grouping based on prefix
# /tmp/ipykernel_44957/2450532689.py:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   e = pd.Series()
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 31
#
#
# Selecting files with prefix anode
# Done: found 31
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-15-21/10kV-pmts and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 9183
#
#
# Selecting files with prefix anode
# Done: found 9226
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-15-21/5kV-glitch and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 14
#
#
# Selecting files with prefix anode
# Done: found 14
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-15-21/5kV-pmts and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 8341
#
#
# Selecting files with prefix anode
# Done: found 8788
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-16-21/10kV-glitch and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 2492
#
#
# Selecting files with prefix anode
# Done: found 2496
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-18-21/13-5kV-pmts and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 2959
#
#
# Selecting files with prefix anode
# Done: found 2953
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-19-21/15kV-pmts/ and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 8007
#
#
# Selecting files with prefix anode
# Done: found 8141
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-19-21/12kV-glitch and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 977
#
#
# Selecting files with prefix anode
# Done: found 980
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-19-21/13-5kV-pmts and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 7273
#
#
# Selecting files with prefix anode
# Done: found 8674
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-19-21/15kV-glitch and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 4533
#
#
# Selecting files with prefix anode
# Done: found 4538
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-19-21/17-5kV-glitch and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 31405
#
#
# Selecting files with prefix anode
# Done: found 35614
#
#
# Looking through files in directory /home/esiii_lxe/HV-test/8-19-21/17-5kV-pmts and grouping based on prefix
# 0it [00:00, ?it/s]
# Selecting files with prefix pmt
# Done: found 43639
#
#
# Selecting files with prefix anode
# Done: found 23824
#
#
# <bound method NDFrame.head of                      name                                                pmt  \
# 0     8-15-21/10kV-glitch  [pmt16.19.04.11.028.csv, pmt16.19.04.11.225.cs...
# 1       8-15-21/10kV-pmts  [pmt16.17.47.22.616.csv, pmt16.17.47.22.672.cs...
# 2      8-15-21/5kV-glitch  [pmt16.17.23.34.934.csv, pmt16.17.28.09.135.cs...
# 3        8-15-21/5kV-pmts  [pmt16.16.15.16.780.csv, pmt16.16.15.17.420.cs...
# 4     8-16-21/10kV-glitch  [pmt17.14.27.02.524.csv, pmt17.14.28.04.504.cs...
# 5     8-18-21/13-5kV-pmts  [pmt18.11.08.13.490.csv, pmt18.11.08.13.546.cs...
# 6      8-19-21/15kV-pmts/  [pmt19.14.16.50.707.csv, pmt19.14.16.50.825.cs...
# 7     8-19-21/12kV-glitch  [pmt19.10.03.09.471.csv, pmt19.10.03.10.611.cs...
# 8     8-19-21/13-5kV-pmts  [pmt19.10.39.11.782.csv, pmt19.10.39.11.944.cs...
# 9     8-19-21/15kV-glitch  [pmt19.15.05.36.611.csv, pmt19.15.05.39.671.cs...
# 10  8-19-21/17-5kV-glitch  [pmt19.21.03.23.473.csv, pmt19.21.03.26.993.cs...
# 11    8-19-21/17-5kV-pmts  [pmt19.17.15.15.610.csv, pmt19.17.15.15.651.cs...
#
#                                                 anode
# 0   [anode16.19.04.11.027.csv, anode16.19.04.11.22...
# 1   [anode16.17.47.24.559.csv, anode16.17.47.24.78...
# 2   [anode16.17.23.34.935.csv, anode16.17.28.09.14...
# 3   [anode16.16.15.18.240.csv, anode16.16.15.19.36...
# 4   [anode17.14.26.55.086.csv, anode17.14.27.02.55...
# 5   [anode18.11.08.14.981.csv, anode18.11.08.15.05...
# 6   [anode19.14.16.47.457.csv, anode19.14.16.47.89...
# 7   [anode19.10.03.07.896.csv, anode19.10.03.08.42...
# 8   [anode19.10.39.10.026.csv, anode19.10.39.11.02...
# 9   [anode19.15.05.36.610.csv, anode19.15.05.39.67...
# 10  [anode19.21.03.23.470.csv, anode19.21.03.26.99...
# 11  [anode19.17.15.12.925.csv, anode19.17.15.12.95...  >

# %%
timestamps_df.to_hdf("controlrun0_timestamps.h5", key='controlrun0')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_44957/2789723045.py in <module>
# ----> 1 timestamps_df.to_hdf("controlrun0_timestamps.h5", key='controlrun0')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in to_hdf(self, path_or_buf, key, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#    2701         from pandas.io import pytables
#    2702
# -> 2703         pytables.to_hdf(
#    2704             path_or_buf,
#    2705             key,
#
# ~/.local/lib/python3.8/site-packages/pandas/io/pytables.py in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#     309     path_or_buf = stringify_path(path_or_buf)
#     310     if isinstance(path_or_buf, str):
# --> 311         with HDFStore(
#     312             path_or_buf, mode=mode, complevel=complevel, complib=complib
#     313         ) as store:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     570             raise ValueError("format is not a defined argument for HDFStore")
#     571
# --> 572         tables = import_optional_dependency("tables")
#     573
#     574         if complib is not None and complib not in tables.filters.all_complibs:
#
# ~/.local/lib/python3.8/site-packages/pandas/compat/_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     116     except ImportError:
#     117         if errors == "raise":
# --> 118             raise ImportError(msg) from None
#     119         else:
#     120             return None
#
# ImportError: Missing optional dependency 'tables'.  Use pip or conda to install tables.
